# %% [markdown]
# # **PRAKTIKUM PERTEMUAN 1 DATA SCIENCE**

# %% [markdown]
# Nama : Bintang Hanifatul Manunggal
#
# Nim :  250401020095
#
# Kelas : IF405

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
nama = "Bintang Hanifatul Manunggal"   # String
angkatan = 2025                        # Integer
ipk = 3.88                             # Float
aktif = True                           # Boolean

print(f"Nama      : {nama}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {ipk}")
print(f"Aktif     : {aktif}")
# Out:
# Nama      : Bintang Hanifatul Manunggal
# Angkatan  : 2025
# IPK       : 3.88
# Aktif     : True

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Bintang Hanifatul Manunggal", "Informatika", 2025)
print(hasil)
# Out:
# Hai! Saya Bintang Hanifatul Manunggal dari Informatika, angkatan 2025.

# %% [markdown]
# ### **Kesimpulan**
#
# Pada pertemuan 1 ini, saya telah mempelajari cara menjalankan kode pemrograman secara interaktif dan memahami penggunaan empat tipe data dasar, yaitu teks (string), angka bulat (integer), angka desimal (float), serta nilai logika (boolean) untuk menyusun informasi data diri dengan terstruktur.
#
# Selain itu, saya juga belajar cara mengelompokkan data menggunakan fitur list dan menampilkannya secara rapi menggunakan perintah perulangan. Sebagai penutup, saya mempraktikkan pembuatan fungsi kustom (function) yang mempermudah proses pembuatan teks perkenalan secara otomatis dan efisien.
